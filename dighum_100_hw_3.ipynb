# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# Here, I am just importing the libraries I will be using

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
import numpy as np
# Out:
# Setup Complete

# %% [markdown]
# Here, I am importing even more libraries.

# %%
gun_violence = "/DATA_01-2013_03-2018 (1).tar.gz"

df = pd.read_csv(gun_violence)

df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (9) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    stage3.csv        date  ... state_house_district state_senate_district
# 0    461105.0  2013-01-01  ...                  NaN                   NaN
# 1    460726.0  2013-01-01  ...                 62.0                  35.0
# 2    478855.0  2013-01-01  ...                 56.0                  13.0
# 3    478925.0  2013-01-05  ...                 40.0                  28.0
# 4    478959.0  2013-01-07  ...                 62.0                  27.0
#
# [5 rows x 29 columns]

# %% [markdown]
# Here, I am importing the data set and setting it to be df

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Mounting

# %%
killed_by_state1 = df.groupby("state", as_index=False)["n_killed"].count()
killed_by_state1
# Out:
#                    state  n_killed
# 0                Alabama      5471
# 1                 Alaska      1349
# 2                Arizona      2328
# 3               Arkansas      2842
# 4             California     16306
# 5               Colorado      3201
# 6            Connecticut      3067
# 7               Delaware      1685
# 8   District of Columbia      3195
# 9                Florida     15029
# 10               Georgia      8925
# 11                Hawaii       289
# 12                 Idaho       661
# 13              Illinois     17556
# 14               Indiana      5852
# 15                  Iowa      2517
# 16                Kansas      2145
# 17              Kentucky      4157
# 18             Louisiana      8103
# 19                 Maine       907
# 20              Maryland      5798
# 21         Massachusetts      5981
# 22              Michigan      6136
# 23             Minnesota      2408
# 24           Mississippi      3599
# 25              Missouri      6631
# 26               Montana       638
# 27              Nebraska      1651
# 28                Nevada      1952
# 29         New Hampshire       964
# 30            New Jersey      5387
# 31            New Mexico      1645
# 32              New York      9712
# 33        North Carolina      8739
# 34          North Dakota       573
# 35                  Ohio     10244
# 36              Oklahoma      3455
# 37                Oregon      2286
# 38          Pennsylvania      8929
# 39          Rhode Island       895
# 40        South Carolina      6939
# 41          South Dakota       544
# 42             Tennessee      7626
# 43                 Texas     13577
# 44                  Utah      1072
# 45               Vermont       472
# 46              Virginia      5949
# 47            Washington      3434
# 48         West Virginia      1575
# 49             Wisconsin      4787
# 50               Wyoming       494

# %% [markdown]
# Here, I am making a table with all the states by count

# %%
killed_by_state = df.groupby("state", as_index=False)["n_killed"].sum()
killed_by_state
# Out:
#                    state  n_killed
# 0                Alabama    1880.0
# 1                 Alaska     267.0
# 2                Arizona    1094.0
# 3               Arkansas     773.0
# 4             California    5562.0
# 5               Colorado     796.0
# 6            Connecticut     341.0
# 7               Delaware     217.0
# 8   District of Columbia     459.0
# 9                Florida    3909.0
# 10               Georgia    2456.0
# 11                Hawaii      63.0
# 12                 Idaho     166.0
# 13              Illinois    3409.0
# 14               Indiana    1608.0
# 15                  Iowa     273.0
# 16                Kansas     542.0
# 17              Kentucky    1066.0
# 18             Louisiana    2179.0
# 19                 Maine     112.0
# 20              Maryland    1691.0
# 21         Massachusetts     472.0
# 22              Michigan    1588.0
# 23             Minnesota     461.0
# 24           Mississippi    1176.0
# 25              Missouri    2136.0
# 26               Montana     154.0
# 27              Nebraska     225.0
# 28                Nevada     799.0
# 29         New Hampshire      88.0
# 30            New Jersey    1168.0
# 31            New Mexico     495.0
# 32              New York    1705.0
# 33        North Carolina    2225.0
# 34          North Dakota      69.0
# 35                  Ohio    2508.0
# 36              Oklahoma     941.0
# 37                Oregon     446.0
# 38          Pennsylvania    2395.0
# 39          Rhode Island      63.0
# 40        South Carolina    1610.0
# 41          South Dakota      90.0
# 42             Tennessee    1824.0
# 43                 Texas    5046.0
# 44                  Utah     282.0
# 45               Vermont      57.0
# 46              Virginia    1459.0
# 47            Washington     853.0
# 48         West Virginia     335.0
# 49             Wisconsin     862.0
# 50               Wyoming      73.0

# %% [markdown]
# Making a table by total deaths per state

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,10))

# Add title
plt.title("Total Number of People Killed, per State")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x=killed_by_state["n_killed"], y=killed_by_state["state"])

# Add label for vertical axis
plt.ylabel("State")
plt.xlabel("Total Number Killed")
# Out:
# Text(0.5, 0, 'Total Number Killed')

# %% [markdown]
# Making a graph of total deaths per state

# %%
df['year'] = pd.DatetimeIndex(df['date']).year
df['month'] = pd.DatetimeIndex(df['date']).month
df['month']
# Out:
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         1.0
#          ...
# 239673    3.0
# 239674    3.0
# 239675    3.0
# 239676    3.0
# 239677    NaN
# Name: month, Length: 239678, dtype: float64

# %% [markdown]
# Adding year and month columns that correspond to numeric values.

# %%
killed_over_time = df.groupby("year", as_index=False)["n_killed"].sum()

killed_over_time
# Out:
#      year  n_killed
# 0  2013.0     317.0
# 1  2014.0   12557.0
# 2  2015.0   13484.0
# 3  2016.0   15066.0
# 4  2017.0   15511.0
# 5  2018.0    3533.0

# %% [markdown]
# making a graph of the total number of deaths per year

# %%
df
# Out:
#         stage3.csv        date  ...    year month
# 0         461105.0  2013-01-01  ...  2013.0   1.0
# 1         460726.0  2013-01-01  ...  2013.0   1.0
# 2         478855.0  2013-01-01  ...  2013.0   1.0
# 3         478925.0  2013-01-05  ...  2013.0   1.0
# 4         478959.0  2013-01-07  ...  2013.0   1.0
# ...            ...         ...  ...     ...   ...
# 239673   1083139.0  2018-03-31  ...  2018.0   3.0
# 239674   1083151.0  2018-03-31  ...  2018.0   3.0
# 239675   1082514.0  2018-03-31  ...  2018.0   3.0
# 239676   1081940.0  2018-03-31  ...  2018.0   3.0
# 239677         NaN         NaN  ...     NaN   NaN
#
# [239678 rows x 31 columns]

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Total Number of Deaths, by Year")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(x= killed_over_time['year'], y= killed_over_time['n_killed'])

# Add label for vertical axis
plt.ylabel("Number of Total d")
# Out:
# Text(0, 0.5, 'Number of Total d')

# %% [markdown]
# Graphing total deaths per year, over time

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(data=killed_over_time, annot=True)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 41.09375, 'Airline')

# %% [markdown]
# Tried to make a heatmap but it didn't work out

# %%
sns.scatterplot(x=df['month'], y=df['n_killed'])

# %% [markdown]
# scatterplot of total people killed per month

# %%
df['n_injured'].mean()
# Out:
# 0.4940065171042695

# %%
killed_by_month = df.groupby("month", as_index=False)["n_injured"].mean()

killed_by_month
# Out:
#     month  n_injured
# 0     1.0   0.474038
# 1     2.0   0.446898
# 2     3.0   0.462677
# 3     4.0   0.478151
# 4     5.0   0.513999
# 5     6.0   0.522367
# 6     7.0   0.532945
# 7     8.0   0.513736
# 8     9.0   0.496846
# 9    10.0   0.490498
# 10   11.0   0.505564
# 11   12.0   0.493538

# %% [markdown]
# Grouping to show a average injuries per month

# %%
plt.plot(killed_by_month['month'],killed_by_month['n_injured'])
plt.title('Average Gun Injuries Per Month')
plt.xlabel('Average Number of Injuries')
plt.ylabel('Month')
plt.show()

# %% [markdown]
# making a visualization of total number of injuries over time.
